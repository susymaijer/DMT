# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
test = pd.read_csv("data/test_set_VU_DM.csv")
train = pd.read_csv("data/training_set_VU_DM.csv")

# %%
for search in train.srch_id.unique()[0:1]:
    train_search = train.loc[train.srch_id == search]
    print(train_search)
# Out:
#     srch_id            date_time  site_id  visitor_location_country_id  \
# 0         1  2013-04-04 08:32:15       12                          187
# 1         1  2013-04-04 08:32:15       12                          187
# 2         1  2013-04-04 08:32:15       12                          187
# 3         1  2013-04-04 08:32:15       12                          187
# 4         1  2013-04-04 08:32:15       12                          187
# 5         1  2013-04-04 08:32:15       12                          187
# 6         1  2013-04-04 08:32:15       12                          187
# 7         1  2013-04-04 08:32:15       12                          187
# 8         1  2013-04-04 08:32:15       12                          187
# 9         1  2013-04-04 08:32:15       12                          187
# 10        1  2013-04-04 08:32:15       12                          187
# 11        1  2013-04-04 08:32:15       12                          187
# ...

# %%
train.head(n=10)
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
# 5        1  2013-04-04 08:32:15       12                          187
# 6        1  2013-04-04 08:32:15       12                          187
# 7        1  2013-04-04 08:32:15       12                          187
# 8        1  2013-04-04 08:32:15       12                          187
# 9        1  2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# ...

# %%
train.loc[(train.site_id == 24) & (train.visitor_location_country_id == 216) & (train.prop_country_id == 219) & (train.prop_id == 3180)]
# Out:
#          srch_id            date_time  site_id  visitor_location_country_id  \
# 1913471   128450  2012-11-09 11:29:34       24                          216
# 3242288   217751  2013-04-29 17:59:08       24                          216
# 3542953   237903  2013-04-15 15:59:36       24                          216
# 4302983   288724  2013-05-06 11:48:06       24                          216
#
#          visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  \
# 1913471                      NaN                   NaN              219
# 3242288                      NaN                   NaN              219
# 3542953                      NaN                   NaN              219
# 4302983                      NaN                   NaN              219
#
#          prop_id  prop_starrating  prop_review_score  prop_brand_bool  \
# 1913471     3180                3                4.5                1
# 3242288     3180                3                4.5                1
# ...
